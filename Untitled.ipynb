# %% [markdown]
# # Exploratory Data Analysis - Retail

# %% [markdown]
# ### Sumitted by AKSHAYA DINESH

# %% [markdown]
# ### Objectives

# %% [markdown]
# *  Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# * As a business manager, try to find out the weak areas where you can work to make more profit.
#
# *  What all business problems you can derive by exploring the data?

# %% [markdown]
# Data set: https://bit.ly/3i4rbWl

# %%
# import all the libaries 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
# load the dataset
data=pd.read_csv("SampleSuperstore.csv")

# %%
#display first 10 rows of data
data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
# to know how many data points ad features
data.shape
# Out:
# (9994, 13)

# %%
# to know the column names
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#statisticalinformation about the data
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# * In the 5 column values there are 9994 data points. hence no null values
# * The maximum quantity is 14 and minimum quantity is 1.
# * There is mean profit of 28.6568 and maximum profit of 8399.97

# %%
# compare linear relationships between attributes using correlation coefficient generated using
    # correlation matrix
sns.heatmap(data.corr(), cmap = 'PuBu', annot = True)
plt.show()

# %% [markdown]
# * A correlation heatmap is used to list all the correlation coefficients in order to identify multicollinearity, in other words high intercorrelation above an absolute value of 0.5 between the a pair of attributes.
# * The correlation will compare and describe the linear connection and relationship between pairs of features, through the type of correlation and its strength. A positive correlation indicates that both features will change their values in the same direction, while a negative correlation indicates that both will change in opposite directions. The larger the correlation strength, the stronger the connection and relationship.
# * From the above heatmap it is clear that Sales and profit are positively correlated.
# * profit and discount are negatevely correlated and quantity and discount are less correlated.

# %%
# postal code is not much important in this analysis hence we can eleminate it.
col=['Postal Code']
data_1=data.drop(columns=col,axis=1)

# %%
#Correlation Between Variables.
data_1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
data_1.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=data_1)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
data_1['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=data_1['State'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Superstore has the notable highest dealings in the state of California, with almost 2K of total dealings.
#   With a big trailing gap, New York has the second highest dealings, with around 1,125 of total dealings.
#   Texas is third with almost 1K of total dealings.
#
# * The states of District of Columbia, Maine, North Dakota, West Virginia, and Wyoming have comparatively negligible dealings.     Even if the Superstore outlets here are newly opened, marketing strategies should be improved in these areas as well as the     states with less than 100 total dealings.

# %% [markdown]
# As we know that profit and sales are moderately correlated.

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data_1['Sales'],color='red',label='Sales',shade=True,bw=25)
sns.kdeplot(data_1['Profit'],color='Blue',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()

# %% [markdown]
# In overall the profit is more than the sales.In some areas it can also increase.

# %%
# average Discount for each State
df_state_profit = data_1.groupby('State')['Discount'].mean().sort_values(ascending = False).plot.bar(figsize = (15, 5), 
                                                                                                 color = 'Cornflowerblue')
plt.ylabel('Average Discount')
plt.xlabel('American States')
plt.title('Average State-Wise Discount', fontsize = 20)
plt.show()

# %% [markdown]
# ### Count plot

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(data_1['Category'],ax=axs[0][0])
sns.countplot(data_1['Segment'],ax=axs[0][1])
sns.countplot(data_1['Ship Mode'],ax=axs[1][0])
sns.countplot(data_1['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)


plt.tight_layout()

# %% [markdown]
# * In category,Office Supplies Category is the most demanded .
# * About 5800 items are transported in Standard class ship mode.
# * The west region is purchesed more item and south is the least.

# %%
data_1.hist(bins=50 ,figsize=(20,15))
plt.show();

# %%
plt.figure(figsize=(20,8))
sns.countplot(data_1['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5,1,'Sub-Category')

# %% [markdown]
# * The most puchased item are binders and papers, least is copiers.

# %% [markdown]
# ### Analysing relation between Category and profit , discount, sales

# %%
data_category = data_1.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
data_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
data_category.plot.pie(subplots=True, 
                     figsize=(15, 5), 
                     autopct='%1.1f%%', 
                     labels = data_category.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002024D3CAC50>,
# ...
#       dtype=object)

# %% [markdown]
# * From the pie graph it is clear that about 50% sales are taking place in the feild of technology.
# * And this same catagory technology making more profit than all others. So should give more importance there ,having 75% profit.
# * Sales of  Funiture is about 38% but it is giving least profit . So have to focus on it to make more profit. The discount         percentage is comparetevely more in furniture.

# %% [markdown]
# ## Sub-Category wise Sales, Profit and Discount

# %%
data_sub_category = data_1.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
data_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %%
plt.figure(figsize = (15,15))
plt.pie(data_sub_category['Sales'], labels = data_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# *  pie chart is a very useful representation of all the data availabe for analysis.
# * From the above diagram it is clear that copiear is the most saled one and fasteners is the least saled .
# * Machines also have relatively higher sales about 22.3%.
# *  chair, table and bookcases have moderate sales , make more advancement in their development and sales that can make more demand to this product

# %%
data_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (10,5),
                                                              label=['Avg Sales Price($)','Profit($)'])

# %% [markdown]
# * Copiers have high sales as well as profit.
# * Mechines have very small valueof profit eventhough it have more sale.

# %%
figsize=(15,10)
sns.pairplot(data_1,hue='Sub-Category')

# %% [markdown]
# ## Cluster analysis

# %%
x = data_1.iloc[:, [9, 10, 11, 12]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0).fit(x)
    wcss.append(kmeans.inertia_)

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(data_1, hue ="Sub-Category").map(plt.scatter,'Sales','Quantity')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the Above data Visualization and Clustering we can see that in Which states and in which Category Sales and profits are High or less,We can improve in that States By Providing Discounts in prefered Range so that Company and cosumer both will be in profit.So For Deciding that Range we have to do some Technical Analysis.One can Do it through Factor Analysis,or also can Do it throgh neural networks.

# %% [markdown]
# * Profit is more than that of sale but there are some areas where profit could be increased.
#
# * Profit and Discount is high in First Class
#
# * Sub-category: Copier: High Profit & sales
#
# * Sub-category: Binders , Machines and then tables have high Discount.
#
# * Category: Maximun sales and Profit obtain in Technology.
#
# * Category: Minimun profit obtain in Furniture
#
# * State: Vermont: Highest Profit
#
# * State: Ohio: Lowest Profit
#
# * Segment: Home-office: High Profit & sales
#
# * Here is top 3 city where deals are Highest.
#
#    1. New York City
#
#    2. Los Angeles
#
#    3. Philadelphia
#
# * Sales and Profit are Moderately Correlated.
#
# * Quantity and Profit are less Moderately Correlated.
#
# * Discount and Profit are Negatively Correlated
#
# * Here is top 3 state where deals are Highest.
#
#     1. Califonia
#
#     2. New York
#     3. Texas

# %% [markdown]
# # THANK YOU
